# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('../HealthInsurancePredictor/data/customer_test_masked.csv')

df.head()
# Out:
#    Unnamed: 0        custid     sex is_employed    income marital_status  \
# 0        4523  001115999_01    Male         NaN   28900.0        Married
# 1       58780  000566299_01    Male        True   40000.0  Never married
# 2       18628  001397329_01  Female        True  203000.0        Married
# 3       11525  000843100_01  Female         NaN       0.0        Married
# 4       56266  000260071_03    Male        True   40000.0        Married
#
#    health_ins                  housing_type  num_vehicles  age state_of_res  \
# 0         NaN      Homeowner free and clear           1.0   82     Arkansas
# 1         NaN                        Rented           1.0   40   New Mexico
# 2         NaN  Homeowner with mortgage/loan           3.0   54     Colorado
# 3         NaN      Homeowner free and clear           1.0   64   California
# 4         NaN  Homeowner with mortgage/loan           4.0   35   New Jersey
#
#    code_column  gas_usage  rooms recent_move_b
# 0          653       20.0      6             F
# 1          404       40.0      5             T
# 2         1291       80.0      2             F
# 3         8962       30.0      2             F
# 4         2059      150.0      1             F

# %%
# Drop unnecessary columns
df = df.drop(columns=['Unnamed: 0', 'code_column'], errors='ignore')

df.set_index('custid', inplace=True)

df.head()
# Out:
#                  sex is_employed    income marital_status  health_ins  \
# custid
# 001115999_01    Male         NaN   28900.0        Married         NaN
# 000566299_01    Male        True   40000.0  Never married         NaN
# 001397329_01  Female        True  203000.0        Married         NaN
# 000843100_01  Female         NaN       0.0        Married         NaN
# 000260071_03    Male        True   40000.0        Married         NaN
#
#                               housing_type  num_vehicles  age state_of_res  \
# custid
# 001115999_01      Homeowner free and clear           1.0   82     Arkansas
# 000566299_01                        Rented           1.0   40   New Mexico
# 001397329_01  Homeowner with mortgage/loan           3.0   54     Colorado
# 000843100_01      Homeowner free and clear           1.0   64   California
# 000260071_03  Homeowner with mortgage/loan           4.0   35   New Jersey
#
#               gas_usage  rooms recent_move_b
# custid
# 001115999_01       20.0      6             F
# 000566299_01       40.0      5             T
# 001397329_01       80.0      2             F
# 000843100_01       30.0      2             F
# 000260071_03      150.0      1             F

# %%
# Print the number of null values for each column
print("\nNull values per column:")
print(df.isnull().sum())
# Out:
# Null values per column:
# sex                 0
# is_employed       259
# income              0
# marital_status      0
# health_ins        804
# housing_type       34
# num_vehicles       34
# age                 0
# state_of_res        0
# gas_usage          34
# rooms               0
# recent_move_b      34
# dtype: int64

# %%
# Check for missing rows in the four columns
missing_housing = df['housing_type'].isnull()
missing_vehicles = df['num_vehicles'].isnull()
missing_gas = df['gas_usage'].isnull()
missing_recent_move = df['recent_move_b'].isnull()

# Combine the masks using logical AND
combined_missing = missing_housing & missing_vehicles & missing_gas & missing_recent_move

# Verify if the counts match and print results
print("Total missing in housing_type:", missing_housing.sum())
print("Total missing in num_vehicles:", missing_vehicles.sum())
print("Total missing in gas_usage:", missing_gas.sum())
print("Total missing in recent_move_b:", missing_recent_move.sum())
print("Rows missing in all four columns:", combined_missing.sum())
# Out:
# Total missing in housing_type: 34
# Total missing in num_vehicles: 34
# Total missing in gas_usage: 34
# Total missing in recent_move_b: 34
# Rows missing in all four columns: 34

# %%
# Create a copy of the dataset to store transformations
df_processed = df.copy()

# Convert NaN values in 'is_employed' to 'Not in Workforce'
df_processed['is_employed'] = df_processed['is_employed'].fillna('Not in Workforce')

df_processed.head()
# Out:
#                  sex       is_employed    income marital_status  health_ins  \
# custid
# 001115999_01    Male  Not in Workforce   28900.0        Married         NaN
# 000566299_01    Male              True   40000.0  Never married         NaN
# 001397329_01  Female              True  203000.0        Married         NaN
# 000843100_01  Female  Not in Workforce       0.0        Married         NaN
# 000260071_03    Male              True   40000.0        Married         NaN
#
#                               housing_type  num_vehicles  age state_of_res  \
# custid
# 001115999_01      Homeowner free and clear           1.0   82     Arkansas
# 000566299_01                        Rented           1.0   40   New Mexico
# 001397329_01  Homeowner with mortgage/loan           3.0   54     Colorado
# 000843100_01      Homeowner free and clear           1.0   64   California
# 000260071_03  Homeowner with mortgage/loan           4.0   35   New Jersey
#
#               gas_usage  rooms recent_move_b
# custid
# 001115999_01       20.0      6             F
# 000566299_01       40.0      5             T
# 001397329_01       80.0      2             F
# 000843100_01       30.0      2             F
# 000260071_03      150.0      1             F

# %%
# Print the number of null values for each column
print("\nNull values per column:")
print(df_processed.isnull().sum())
# Out:
# Null values per column:
# sex                 0
# is_employed         0
# income              0
# marital_status      0
# health_ins        804
# housing_type       34
# num_vehicles       34
# age                 0
# state_of_res        0
# gas_usage          34
# rooms               0
# recent_move_b      34
# dtype: int64

# %%
# Impute NaN values using median or mode from the training dataset
df_processed['housing_type'] = df_processed['housing_type'].fillna(df_processed['housing_type'].mode()[0])
df_processed['num_vehicles'] = df_processed['num_vehicles'].fillna(df_processed['num_vehicles'].median())
df_processed['gas_usage'] = df_processed['gas_usage'].fillna(df_processed['gas_usage'].median())
df_processed['recent_move_b'] = df_processed['recent_move_b'].fillna(df_processed['recent_move_b'].mode()[0])

# %%
# Print the number of null values for each column
print("\nNull values per column:")
print(df_processed.isnull().sum())
# Out:
# Null values per column:
# sex                 0
# is_employed         0
# income              0
# marital_status      0
# health_ins        804
# housing_type        0
# num_vehicles        0
# age                 0
# state_of_res        0
# gas_usage           0
# rooms               0
# recent_move_b       0
# dtype: int64

# %%
df_processed.head()
# Out:
#                  sex       is_employed    income marital_status  health_ins  \
# custid
# 001115999_01    Male  Not in Workforce   28900.0        Married         NaN
# 000566299_01    Male              True   40000.0  Never married         NaN
# 001397329_01  Female              True  203000.0        Married         NaN
# 000843100_01  Female  Not in Workforce       0.0        Married         NaN
# 000260071_03    Male              True   40000.0        Married         NaN
#
#                               housing_type  num_vehicles  age state_of_res  \
# custid
# 001115999_01      Homeowner free and clear           1.0   82     Arkansas
# 000566299_01                        Rented           1.0   40   New Mexico
# 001397329_01  Homeowner with mortgage/loan           3.0   54     Colorado
# 000843100_01      Homeowner free and clear           1.0   64   California
# 000260071_03  Homeowner with mortgage/loan           4.0   35   New Jersey
#
#               gas_usage  rooms recent_move_b
# custid
# 001115999_01       20.0      6             F
# 000566299_01       40.0      5             T
# 001397329_01       80.0      2             F
# 000843100_01       30.0      2             F
# 000260071_03      150.0      1             F

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Create a copy of the dataset to store transformations
df_transformed = df_processed.copy()

# Identify categorical columns
categorical_cols = df_transformed.select_dtypes(include=['object']).columns

# Identify binary columns
binary_cols = df_transformed.select_dtypes(include=['bool']).columns

# Convert binary columns to strings
for column in binary_cols:
    df_transformed[column] = df_transformed[column].astype(str)

# Convert categorical columns to strings
for column in categorical_cols:
    df_transformed[column] = df_transformed[column].astype(str)

# Initialize LabelEncoder for binary columns
label_encoders = {}
for column in binary_cols:
    le = LabelEncoder()
    df_transformed[column] = le.fit_transform(df_transformed[column])
    label_encoders[column] = le

# Initialize OneHotEncoder for categorical columns
onehot_encoder = OneHotEncoder(drop='first', sparse_output=False)

# Apply OneHotEncoder to categorical columns
df_encoded = pd.DataFrame(onehot_encoder.fit_transform(df_transformed[categorical_cols]), columns=onehot_encoder.get_feature_names_out(categorical_cols))

# Drop original categorical columns and concatenate encoded columns
df_transformed = df_transformed.drop(columns=categorical_cols).reset_index(drop=True)
df_transformed = pd.concat([df_transformed, df_encoded], axis=1)

df_transformed.index = df_processed.index
df_transformed.index.name = 'custid'

# %%
pd.set_option('display.max_columns', None)
df_transformed.head()
# Out:
#                 income  health_ins  num_vehicles  age  gas_usage  rooms  \
# custid
# 001115999_01   28900.0         NaN           1.0   82       20.0      6
# 000566299_01   40000.0         NaN           1.0   40       40.0      5
# 001397329_01  203000.0         NaN           3.0   54       80.0      2
# 000843100_01       0.0         NaN           1.0   64       30.0      2
# 000260071_03   40000.0         NaN           4.0   35      150.0      1
#
#               sex_Male  is_employed_Not in Workforce  is_employed_True  \
# custid
# 001115999_01       1.0                           1.0               0.0
# 000566299_01       1.0                           0.0               1.0
# 001397329_01       0.0                           0.0               1.0
# 000843100_01       0.0                           1.0               0.0
# 000260071_03       1.0                           0.0               1.0
#
#               marital_status_Married  marital_status_Never married  \
# custid
# 001115999_01                     1.0                           0.0
# 000566299_01                     0.0                           1.0
# 001397329_01                     1.0                           0.0
# 000843100_01                     1.0                           0.0
# 000260071_03                     1.0                           0.0
#
#               marital_status_Widowed  \
# custid
# 001115999_01                     0.0
# 000566299_01                     0.0
# 001397329_01                     0.0
# 000843100_01                     0.0
# 000260071_03                     0.0
#
#               housing_type_Homeowner with mortgage/loan  \
# custid
# 001115999_01                                        0.0
# 000566299_01                                        0.0
# 001397329_01                                        1.0
# 000843100_01                                        0.0
# 000260071_03                                        1.0
#
#               housing_type_Occupied with no rent  housing_type_Rented  \
# custid
# 001115999_01                                 0.0                  0.0
# 000566299_01                                 0.0                  1.0
# 001397329_01                                 0.0                  0.0
# 000843100_01                                 0.0                  0.0
# 000260071_03                                 0.0                  0.0
#
#               state_of_res_Alaska  state_of_res_Arizona  \
# custid
# 001115999_01                  0.0                   0.0
# 000566299_01                  0.0                   0.0
# 001397329_01                  0.0                   0.0
# 000843100_01                  0.0                   0.0
# 000260071_03                  0.0                   0.0
#
#               state_of_res_Arkansas  state_of_res_California  \
# custid
# 001115999_01                    1.0                      0.0
# 000566299_01                    0.0                      0.0
# 001397329_01                    0.0                      0.0
# 000843100_01                    0.0                      1.0
# 000260071_03                    0.0                      0.0
#
#               state_of_res_Colorado  state_of_res_Connecticut  \
# custid
# 001115999_01                    0.0                       0.0
# 000566299_01                    0.0                       0.0
# 001397329_01                    1.0                       0.0
# 000843100_01                    0.0                       0.0
# 000260071_03                    0.0                       0.0
#
#               state_of_res_Delaware  state_of_res_District of Columbia  \
# custid
# 001115999_01                    0.0                                0.0
# 000566299_01                    0.0                                0.0
# 001397329_01                    0.0                                0.0
# 000843100_01                    0.0                                0.0
# 000260071_03                    0.0                                0.0
#
#               state_of_res_Florida  state_of_res_Georgia  state_of_res_Idaho  \
# custid
# 001115999_01                   0.0                   0.0                 0.0
# 000566299_01                   0.0                   0.0                 0.0
# 001397329_01                   0.0                   0.0                 0.0
# 000843100_01                   0.0                   0.0                 0.0
# 000260071_03                   0.0                   0.0                 0.0
#
#               state_of_res_Illinois  state_of_res_Indiana  state_of_res_Iowa  \
# custid
# 001115999_01                    0.0                   0.0                0.0
# 000566299_01                    0.0                   0.0                0.0
# 001397329_01                    0.0                   0.0                0.0
# 000843100_01                    0.0                   0.0                0.0
# 000260071_03                    0.0                   0.0                0.0
#
#               state_of_res_Kansas  state_of_res_Kentucky  \
# custid
# 001115999_01                  0.0                    0.0
# 000566299_01                  0.0                    0.0
# 001397329_01                  0.0                    0.0
# 000843100_01                  0.0                    0.0
# 000260071_03                  0.0                    0.0
#
#               state_of_res_Louisiana  state_of_res_Maine  \
# custid
# 001115999_01                     0.0                 0.0
# 000566299_01                     0.0                 0.0
# 001397329_01                     0.0                 0.0
# 000843100_01                     0.0                 0.0
# 000260071_03                     0.0                 0.0
#
#               state_of_res_Maryland  state_of_res_Massachusetts  \
# custid
# 001115999_01                    0.0                         0.0
# 000566299_01                    0.0                         0.0
# 001397329_01                    0.0                         0.0
# 000843100_01                    0.0                         0.0
# 000260071_03                    0.0                         0.0
#
#               state_of_res_Michigan  state_of_res_Minnesota  \
# custid
# 001115999_01                    0.0                     0.0
# 000566299_01                    0.0                     0.0
# 001397329_01                    0.0                     0.0
# 000843100_01                    0.0                     0.0
# 000260071_03                    0.0                     0.0
#
#               state_of_res_Mississippi  state_of_res_Missouri  \
# custid
# 001115999_01                       0.0                    0.0
# 000566299_01                       0.0                    0.0
# 001397329_01                       0.0                    0.0
# 000843100_01                       0.0                    0.0
# 000260071_03                       0.0                    0.0
#
#               state_of_res_Montana  state_of_res_Nebraska  \
# custid
# 001115999_01                   0.0                    0.0
# 000566299_01                   0.0                    0.0
# 001397329_01                   0.0                    0.0
# 000843100_01                   0.0                    0.0
# 000260071_03                   0.0                    0.0
#
#               state_of_res_Nevada  state_of_res_New Hampshire  \
# custid
# 001115999_01                  0.0                         0.0
# 000566299_01                  0.0                         0.0
# 001397329_01                  0.0                         0.0
# 000843100_01                  0.0                         0.0
# 000260071_03                  0.0                         0.0
#
#               state_of_res_New Jersey  state_of_res_New Mexico  \
# custid
# 001115999_01                      0.0                      0.0
# 000566299_01                      0.0                      1.0
# 001397329_01                      0.0                      0.0
# 000843100_01                      0.0                      0.0
# 000260071_03                      1.0                      0.0
#
#               state_of_res_New York  state_of_res_North Carolina  \
# custid
# 001115999_01                    0.0                          0.0
# 000566299_01                    0.0                          0.0
# 001397329_01                    0.0                          0.0
# 000843100_01                    0.0                          0.0
# 000260071_03                    0.0                          0.0
#
#               state_of_res_North Dakota  state_of_res_Ohio  \
# custid
# 001115999_01                        0.0                0.0
# 000566299_01                        0.0                0.0
# 001397329_01                        0.0                0.0
# 000843100_01                        0.0                0.0
# 000260071_03                        0.0                0.0
#
#               state_of_res_Oklahoma  state_of_res_Oregon  \
# custid
# 001115999_01                    0.0                  0.0
# 000566299_01                    0.0                  0.0
# 001397329_01                    0.0                  0.0
# 000843100_01                    0.0                  0.0
# 000260071_03                    0.0                  0.0
#
#               state_of_res_Pennsylvania  state_of_res_Rhode Island  \
# custid
# 001115999_01                        0.0                        0.0
# 000566299_01                        0.0                        0.0
# 001397329_01                        0.0                        0.0
# 000843100_01                        0.0                        0.0
# 000260071_03                        0.0                        0.0
#
#               state_of_res_South Carolina  state_of_res_South Dakota  \
# custid
# 001115999_01                          0.0                        0.0
# 000566299_01                          0.0                        0.0
# 001397329_01                          0.0                        0.0
# 000843100_01                          0.0                        0.0
# 000260071_03                          0.0                        0.0
#
#               state_of_res_Tennessee  state_of_res_Texas  state_of_res_Utah  \
# custid
# 001115999_01                     0.0                 0.0                0.0
# 000566299_01                     0.0                 0.0                0.0
# 001397329_01                     0.0                 0.0                0.0
# 000843100_01                     0.0                 0.0                0.0
# 000260071_03                     0.0                 0.0                0.0
#
#               state_of_res_Virginia  state_of_res_Washington  \
# custid
# 001115999_01                    0.0                      0.0
# 000566299_01                    0.0                      0.0
# 001397329_01                    0.0                      0.0
# 000843100_01                    0.0                      0.0
# 000260071_03                    0.0                      0.0
#
#               state_of_res_West Virginia  state_of_res_Wisconsin  \
# custid
# 001115999_01                         0.0                     0.0
# 000566299_01                         0.0                     0.0
# 001397329_01                         0.0                     0.0
# 000843100_01                         0.0                     0.0
# 000260071_03                         0.0                     0.0
#
#               state_of_res_Wyoming  recent_move_b_T
# custid
# 001115999_01                   0.0              0.0
# 000566299_01                   0.0              1.0
# 001397329_01                   0.0              0.0
# 000843100_01                   0.0              0.0
# 000260071_03                   0.0              0.0

# %%
df_transformed.shape
# Out:
# (804, 64)

# %%
import os
# Save the df_transformed dataset to a CSV file in the directory 'data/preprocessed' (create the directory if it does not exist)
output_dir = 'data/preprocessed'
os.makedirs(output_dir, exist_ok=True)
output_file = os.path.join(output_dir, 'customer_test_transformed.csv')
df_transformed.to_csv(output_file, index=True)

# %%
# Load the training dataset
train_file = 'data/preprocessed/customer_transformed.csv'
train_df = pd.read_csv(train_file)

# Load the test dataset
test_file = 'data/preprocessed/customer_test_transformed.csv'
test_df = pd.read_csv(test_file)

# %%
train_df.set_index('custid', inplace=True)
test_df.set_index('custid', inplace=True)

# %%
X_train = train_df.drop(columns=['health_ins'])
y_train = train_df['health_ins']

# %%
from sklearn.linear_model import LogisticRegression

# Initialize the Logistic Regression model
lr = LogisticRegression(max_iter=1000, random_state=42)

# Train the model
lr.fit(X_train, y_train)
# Out:
# C:\Users\eduar\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000, random_state=42)

# %%
# Add missing columns to the test dataset and set their values to 0
missing_columns = ['state_of_res_Hawaii', 'state_of_res_Vermont']
for col in missing_columns:
    if col not in test_df.columns:
        test_df[col] = 0

# %%
# Ensure the test dataset has the same column order as the training dataset
test_df = test_df[X_train.columns]

# Make predictions using the trained model
predictions = lr.predict(test_df)

# %%
test_df.head()
# Out:
#                 income  num_vehicles  age  gas_usage  rooms  sex_Male  \
# custid
# 001115999_01   28900.0           1.0   82       20.0      6       1.0
# 000566299_01   40000.0           1.0   40       40.0      5       1.0
# 001397329_01  203000.0           3.0   54       80.0      2       0.0
# 000843100_01       0.0           1.0   64       30.0      2       0.0
# 000260071_03   40000.0           4.0   35      150.0      1       1.0
#
#               is_employed_Not in Workforce  is_employed_True  \
# custid
# 001115999_01                           1.0               0.0
# 000566299_01                           0.0               1.0
# 001397329_01                           0.0               1.0
# 000843100_01                           1.0               0.0
# 000260071_03                           0.0               1.0
#
#               marital_status_Married  marital_status_Never married  \
# custid
# 001115999_01                     1.0                           0.0
# 000566299_01                     0.0                           1.0
# 001397329_01                     1.0                           0.0
# 000843100_01                     1.0                           0.0
# 000260071_03                     1.0                           0.0
#
#               marital_status_Widowed  \
# custid
# 001115999_01                     0.0
# 000566299_01                     0.0
# 001397329_01                     0.0
# 000843100_01                     0.0
# 000260071_03                     0.0
#
#               housing_type_Homeowner with mortgage/loan  \
# custid
# 001115999_01                                        0.0
# 000566299_01                                        0.0
# 001397329_01                                        1.0
# 000843100_01                                        0.0
# 000260071_03                                        1.0
#
#               housing_type_Occupied with no rent  housing_type_Rented  \
# custid
# 001115999_01                                 0.0                  0.0
# 000566299_01                                 0.0                  1.0
# 001397329_01                                 0.0                  0.0
# 000843100_01                                 0.0                  0.0
# 000260071_03                                 0.0                  0.0
#
#               state_of_res_Alaska  state_of_res_Arizona  \
# custid
# 001115999_01                  0.0                   0.0
# 000566299_01                  0.0                   0.0
# 001397329_01                  0.0                   0.0
# 000843100_01                  0.0                   0.0
# 000260071_03                  0.0                   0.0
#
#               state_of_res_Arkansas  state_of_res_California  \
# custid
# 001115999_01                    1.0                      0.0
# 000566299_01                    0.0                      0.0
# 001397329_01                    0.0                      0.0
# 000843100_01                    0.0                      1.0
# 000260071_03                    0.0                      0.0
#
#               state_of_res_Colorado  state_of_res_Connecticut  \
# custid
# 001115999_01                    0.0                       0.0
# 000566299_01                    0.0                       0.0
# 001397329_01                    1.0                       0.0
# 000843100_01                    0.0                       0.0
# 000260071_03                    0.0                       0.0
#
#               state_of_res_Delaware  state_of_res_District of Columbia  \
# custid
# 001115999_01                    0.0                                0.0
# 000566299_01                    0.0                                0.0
# 001397329_01                    0.0                                0.0
# 000843100_01                    0.0                                0.0
# 000260071_03                    0.0                                0.0
#
#               state_of_res_Florida  state_of_res_Georgia  state_of_res_Hawaii  \
# custid
# 001115999_01                   0.0                   0.0                    0
# 000566299_01                   0.0                   0.0                    0
# 001397329_01                   0.0                   0.0                    0
# 000843100_01                   0.0                   0.0                    0
# 000260071_03                   0.0                   0.0                    0
#
#               state_of_res_Idaho  state_of_res_Illinois  state_of_res_Indiana  \
# custid
# 001115999_01                 0.0                    0.0                   0.0
# 000566299_01                 0.0                    0.0                   0.0
# 001397329_01                 0.0                    0.0                   0.0
# 000843100_01                 0.0                    0.0                   0.0
# 000260071_03                 0.0                    0.0                   0.0
#
#               state_of_res_Iowa  state_of_res_Kansas  state_of_res_Kentucky  \
# custid
# 001115999_01                0.0                  0.0                    0.0
# 000566299_01                0.0                  0.0                    0.0
# 001397329_01                0.0                  0.0                    0.0
# 000843100_01                0.0                  0.0                    0.0
# 000260071_03                0.0                  0.0                    0.0
#
#               state_of_res_Louisiana  state_of_res_Maine  \
# custid
# 001115999_01                     0.0                 0.0
# 000566299_01                     0.0                 0.0
# 001397329_01                     0.0                 0.0
# 000843100_01                     0.0                 0.0
# 000260071_03                     0.0                 0.0
#
#               state_of_res_Maryland  state_of_res_Massachusetts  \
# custid
# 001115999_01                    0.0                         0.0
# 000566299_01                    0.0                         0.0
# 001397329_01                    0.0                         0.0
# 000843100_01                    0.0                         0.0
# 000260071_03                    0.0                         0.0
#
#               state_of_res_Michigan  state_of_res_Minnesota  \
# custid
# 001115999_01                    0.0                     0.0
# 000566299_01                    0.0                     0.0
# 001397329_01                    0.0                     0.0
# 000843100_01                    0.0                     0.0
# 000260071_03                    0.0                     0.0
#
#               state_of_res_Mississippi  state_of_res_Missouri  \
# custid
# 001115999_01                       0.0                    0.0
# 000566299_01                       0.0                    0.0
# 001397329_01                       0.0                    0.0
# 000843100_01                       0.0                    0.0
# 000260071_03                       0.0                    0.0
#
#               state_of_res_Montana  state_of_res_Nebraska  \
# custid
# 001115999_01                   0.0                    0.0
# 000566299_01                   0.0                    0.0
# 001397329_01                   0.0                    0.0
# 000843100_01                   0.0                    0.0
# 000260071_03                   0.0                    0.0
#
#               state_of_res_Nevada  state_of_res_New Hampshire  \
# custid
# 001115999_01                  0.0                         0.0
# 000566299_01                  0.0                         0.0
# 001397329_01                  0.0                         0.0
# 000843100_01                  0.0                         0.0
# 000260071_03                  0.0                         0.0
#
#               state_of_res_New Jersey  state_of_res_New Mexico  \
# custid
# 001115999_01                      0.0                      0.0
# 000566299_01                      0.0                      1.0
# 001397329_01                      0.0                      0.0
# 000843100_01                      0.0                      0.0
# 000260071_03                      1.0                      0.0
#
#               state_of_res_New York  state_of_res_North Carolina  \
# custid
# 001115999_01                    0.0                          0.0
# 000566299_01                    0.0                          0.0
# 001397329_01                    0.0                          0.0
# 000843100_01                    0.0                          0.0
# 000260071_03                    0.0                          0.0
#
#               state_of_res_North Dakota  state_of_res_Ohio  \
# custid
# 001115999_01                        0.0                0.0
# 000566299_01                        0.0                0.0
# 001397329_01                        0.0                0.0
# 000843100_01                        0.0                0.0
# 000260071_03                        0.0                0.0
#
#               state_of_res_Oklahoma  state_of_res_Oregon  \
# custid
# 001115999_01                    0.0                  0.0
# 000566299_01                    0.0                  0.0
# 001397329_01                    0.0                  0.0
# 000843100_01                    0.0                  0.0
# 000260071_03                    0.0                  0.0
#
#               state_of_res_Pennsylvania  state_of_res_Rhode Island  \
# custid
# 001115999_01                        0.0                        0.0
# 000566299_01                        0.0                        0.0
# 001397329_01                        0.0                        0.0
# 000843100_01                        0.0                        0.0
# 000260071_03                        0.0                        0.0
#
#               state_of_res_South Carolina  state_of_res_South Dakota  \
# custid
# 001115999_01                          0.0                        0.0
# 000566299_01                          0.0                        0.0
# 001397329_01                          0.0                        0.0
# 000843100_01                          0.0                        0.0
# 000260071_03                          0.0                        0.0
#
#               state_of_res_Tennessee  state_of_res_Texas  state_of_res_Utah  \
# custid
# 001115999_01                     0.0                 0.0                0.0
# 000566299_01                     0.0                 0.0                0.0
# 001397329_01                     0.0                 0.0                0.0
# 000843100_01                     0.0                 0.0                0.0
# 000260071_03                     0.0                 0.0                0.0
#
#               state_of_res_Vermont  state_of_res_Virginia  \
# custid
# 001115999_01                     0                    0.0
# 000566299_01                     0                    0.0
# 001397329_01                     0                    0.0
# 000843100_01                     0                    0.0
# 000260071_03                     0                    0.0
#
#               state_of_res_Washington  state_of_res_West Virginia  \
# custid
# 001115999_01                      0.0                         0.0
# 000566299_01                      0.0                         0.0
# 001397329_01                      0.0                         0.0
# 000843100_01                      0.0                         0.0
# 000260071_03                      0.0                         0.0
#
#               state_of_res_Wisconsin  state_of_res_Wyoming  recent_move_b_T
# custid
# 001115999_01                     0.0                   0.0              0.0
# 000566299_01                     0.0                   0.0              1.0
# 001397329_01                     0.0                   0.0              0.0
# 000843100_01                     0.0                   0.0              0.0
# 000260071_03                     0.0                   0.0              0.0

# %%
from datetime import datetime
# Add predictions to the test dataset
test_df['health_ins'] = predictions

# Convert boolean predictions to string format (TRUE/FALSE)
test_df['health_ins'] = test_df['health_ins'].apply(lambda x: 'TRUE' if x else 'FALSE')

# Generate the current timestamp
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')

# Format the file name with the timestamp
output_file = f'data/submissions/submission_{timestamp}.csv'
os.makedirs('data/submissions', exist_ok=True)

# Ensure 'custid' is a column in the submission DataFrame
test_df.reset_index(inplace=True)
submission = test_df[['custid', 'health_ins']]

submission.head()

submission.to_csv(output_file, index=False, header=True)
